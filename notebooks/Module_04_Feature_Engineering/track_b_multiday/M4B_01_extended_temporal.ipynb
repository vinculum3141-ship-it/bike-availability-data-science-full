# %% [markdown]
# # M4B_01: Extended Temporal Features for Multi-Day Prediction
#
# **Track B: Regression/Time Series (24-72 Hour Forecasting)**
#
# ## 🎯 Learning Objectives
# - Create extended temporal features for multi-day forecasting
# - Engineer seasonal and holiday indicators
# - Build interaction features (weekend × season)
# - Create lagged features (24hr, 7-day lags)
# - Develop rolling statistics (24hr, 48hr, weekly windows)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Load Data
#
# Load bike availability data for multi-day analysis.

# %%
# TODO: Load and prepare data
df = pd.read_csv('../../../data/raw/sample_bike_weather.csv')
df['timestamp'] = pd.to_datetime(df['timestamp'])
print(f"Dataset shape: {df.shape}")

# %% [markdown]
# ## 2. Extended Temporal Features
#
# Create day-of-week, month, season features.

# %%
# TODO: Create temporal features
# - day_of_week, month, season
# - is_weekend, is_holiday
# - Cyclical encodings for hour, day, month

# %% [markdown]
# ## 3. Lag Features
#
# Create 24-hour and 7-day lag features.

# %%
# TODO: Create lag features
# - bikes_available_lag_24h
# - bikes_available_lag_7d

# %% [markdown]
# ## 4. Rolling Statistics
#
# Calculate rolling means and trends.

# %%
# TODO: Create rolling features
# - rolling_mean_24h, rolling_mean_48h, rolling_mean_7d
# - rolling_std_24h, rolling_std_7d

# %% [markdown]
# ## 5. Interaction Features
#
# Weekend × Season, Holiday × Weather interactions.

# %%
# TODO: Create interaction features

# %% [markdown]
# ## 🔗 Next Steps
# - M4B_02: Weather forecast features
# - M4B_03: Event calendar features
