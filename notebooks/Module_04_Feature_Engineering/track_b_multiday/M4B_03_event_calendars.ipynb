# %% [markdown]
# # M4B_03: Event Calendar Features
#
# **Track B: Multi-Day Tourist Prediction**
#
# ## 🎯 Learning Objectives
# - Integrate event calendars (festivals, conferences)
# - Create tourist season indicators
# - Build major event features
# - Engineer school holiday indicators

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## TODO: Implement event calendar features
# - Major events in Amsterdam
# - Concert/sports indicators
# - Tourist season (high/low)
# - School holidays
# - Festival calendars

# %% [markdown]
# ## 🔗 Next: Module 5 Track B - Regression & Time Series Models
