# %% [markdown]
# # M4B_02: Weather Forecast Features
#
# **Track B: 24-72 Hour Forecasting**
#
# ## 🎯 Learning Objectives
# - Use weather forecasts (not current conditions)
# - Create 24-72 hour forecast features
# - Engineer weather trend indicators
# - Build aggregate forecast features

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## TODO: Implement weather forecast features
# - Temperature forecasts (24h, 48h, 72h ahead)
# - Precipitation probability
# - Weather trend indicators
# - Aggregate forecasts

# %% [markdown]
# ## 🔗 Next: M4B_03 Event calendar features
