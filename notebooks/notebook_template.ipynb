# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vinculum3141-ship-it/bike-availability-data-science/blob/main/notebooks/notebook_template.ipynb)

# %% [markdown]
# # 📓 Notebook Template
#
# **Purpose**: [Describe what this notebook does]
# **Module**: [e.g., Module 02 - Data Acquisition]
# **Author**: [Your Name]
# **Date**: [YYYY-MM-DD]
#
# ---
#
# ## 📋 Overview
#
# Brief description of what you'll accomplish in this notebook:
# - [ ] Task 1
# - [ ] Task 2
# - [ ] Task 3

# %% [markdown]
# ## 🔧 Setup
#
# Run this cell first to set up the environment.

# %%
# ═══════════════════════════════════════════════════════════
# 1. IMPORTS
# ═══════════════════════════════════════════════════════════

# Standard library
import os
import sys
from datetime import datetime

# Third-party imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configure pandas display
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Configure plotting
plt.style.use('seaborn-v0_8-darkgrid')
# %matplotlib inline

# Check if running in Google Colab
if 'google.colab' in sys.modules:
    print("📍 Running in Google Colab")
    # Uncomment to clone repository
    # !git clone https://github.com/[username]/bike-availability-data-science.git
    # %cd bike-availability-data-science
    # !pip install -q -r requirements.txt
else:
    print("📍 Running locally")

# Add project root to path
project_root = os.path.abspath('..' if 'notebooks' in os.getcwd() else '.')
if project_root not in sys.path:
    sys.path.append(project_root)

print("✅ Setup complete!")
print(f"📁 Working directory: {os.getcwd()}")
print(f"🐍 Python version: {sys.version.split()[0]}")

# %% [markdown]
# ## ⚙️ Configuration
#
# Define constants and configuration parameters.

# %%
# ═══════════════════════════════════════════════════════════
# 2. CONFIGURATION
# ═══════════════════════════════════════════════════════════

# Random seed for reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# File paths
DATA_DIR = 'data/raw'
OUTPUT_DIR = 'data/processed'
RESULTS_DIR = 'results'

# Create directories if they don't exist
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(RESULTS_DIR, exist_ok=True)

# Other configuration
FIGURE_SIZE = (12, 6)

print("✅ Configuration set")

# %% [markdown]
# ## 📥 Load Data
#
# Load and inspect the data.

# %%
# ═══════════════════════════════════════════════════════════
# 3. DATA LOADING
# ═══════════════════════════════════════════════════════════

# TODO: Load your data here
# df = pd.read_csv(os.path.join(DATA_DIR, 'your_file.csv'))

# Example data for demonstration
df = pd.DataFrame({
    'timestamp': pd.date_range('2024-01-01', periods=100, freq='H'),
    'bikes_available': np.random.randint(0, 20, 100),
    'station_id': np.random.choice(['A', 'B', 'C'], 100)
})

print(f"✅ Loaded {len(df):,} rows and {len(df.columns)} columns")
print(f"📅 Date range: {df['timestamp'].min()} to {df['timestamp'].max()}")

# %% [markdown]
# ## 🔍 Quick Data Inspection

# %%
# Display first few rows
print("📊 First 5 rows:")
display(df.head())

print("\n" + "="*60)
print("📋 Dataset Info:")
print("="*60)
df.info()

print("\n" + "="*60)
print("📈 Summary Statistics:")
print("="*60)
display(df.describe())

print("\n" + "="*60)
print("❓ Missing Values:")
print("="*60)
missing = df.isnull().sum()
if missing.sum() > 0:
    print(missing[missing > 0])
else:
    print("✅ No missing values")

# %% [markdown]
# ---
# ## 💡 Your Analysis Starts Here
#
# Add your analysis sections below. Use clear markdown headers to organize your work.

# %% [markdown]
# ### Section 1: [Your Section Title]
#
# Describe what you're doing in this section.

# %%
# Your code here

pass

# %% [markdown]
# ### Section 2: [Your Section Title]
#
# Describe what you're doing in this section.

# %%
# Your code here

pass

# %% [markdown]
# ---
# ## 💾 Save Results
#
# Save any processed data or results.

# %%
# ═══════════════════════════════════════════════════════════
# SAVE OUTPUTS
# ═══════════════════════════════════════════════════════════

# Example: Save processed data
# output_file = os.path.join(OUTPUT_DIR, 'processed_data.csv')
# df_processed.to_csv(output_file, index=False)
# print(f"✅ Saved processed data to {output_file}")

# Example: Save figures
# fig_file = os.path.join(RESULTS_DIR, 'analysis_plot.png')
# plt.savefig(fig_file, dpi=300, bbox_inches='tight')
# print(f"✅ Saved figure to {fig_file}")

print("✅ All outputs saved")

# %% [markdown]
# ---
# ## 📝 Summary
#
# Summarize your key findings:
#
# ### Key Findings
# 1. **Finding 1**: [Description]
# 2. **Finding 2**: [Description]
# 3. **Finding 3**: [Description]
#
# ### Next Steps
# - [ ] [Action item 1]
# - [ ] [Action item 2]
# - [ ] [Action item 3]
#
# ### Challenges & Lessons Learned
# - **Challenge**: [What was difficult]
#   - **Solution**: [How you solved it]
# - **Lesson**: [What you learned]

# %% [markdown]
# ---
# ## 📚 References
#
# - [Link to documentation]
# - [Link to related notebooks]
# - [Link to data sources]
