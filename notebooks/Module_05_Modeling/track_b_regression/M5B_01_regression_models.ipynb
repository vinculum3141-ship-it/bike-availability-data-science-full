# %% [markdown]
# # M5B_01: Regression Models
#
# **Track B: Multi-Day Prediction**
#
# ## 🎯 Learning Objectives
# - Train regression models (Linear, Ridge, RF, XGBoost)
# - Compare RMSE, MAE, R²
# - Handle temporal data splits
# - Feature importance analysis

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb

# %% [markdown]
# ## TODO: Implement regression models
# - Linear Regression baseline
# - Ridge/Lasso regularization
# - Random Forest Regressor
# - XGBoost Regressor
# - Time-series aware train/val/test splits
# - Compare RMSE, MAE, MAPE, R²

# %% [markdown]
# ## 🔗 Next: M5B_02 Time series models (ARIMA, Prophet)
