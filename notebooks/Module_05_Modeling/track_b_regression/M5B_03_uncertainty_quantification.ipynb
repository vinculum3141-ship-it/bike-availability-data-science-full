# %% [markdown]
# # M5B_03: Uncertainty Quantification
#
# **Track B: Prediction Intervals & Confidence**
#
# ## 🎯 Learning Objectives
# - Build prediction intervals
# - Quantile regression
# - Probabilistic forecasting
# - Ensemble methods for uncertainty

# %%
from sklearn.ensemble import GradientBoostingRegressor
import numpy as np

# %% [markdown]
# ## TODO: Implement uncertainty quantification
# - Prediction intervals (95% confidence)
# - Quantile regression (10th, 50th, 90th percentiles)
# - Ensemble variance as uncertainty measure
# - Probabilistic forecasting with Prophet
# - Visualize uncertainty bands
# - Communicate ranges to users

# %% [markdown]
# ## 🔗 Next: Module 6 - Time Series Validation & Backtesting
