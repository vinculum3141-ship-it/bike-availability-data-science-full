# %% [markdown]
# # M5B_02: Time Series Models
#
# **Track B: ARIMA & Prophet**
#
# ## 🎯 Learning Objectives
# - Build ARIMA/SARIMA models
# - Train Prophet for forecasting
# - Multi-step ahead predictions (24h, 48h, 72h)
# - Seasonality and trend decomposition

# %%
from statsmodels.tsa.arima.model import ARIMA
from prophet import Prophet

# %% [markdown]
# ## TODO: Implement time series models
# - ARIMA for univariate forecasting
# - SARIMA for seasonal patterns
# - Prophet with holidays and events
# - Multi-horizon forecasts (24h, 48h, 72h)
# - Forecast accuracy evaluation
# - Decomposition analysis

# %% [markdown]
# ## 🔗 Next: M5B_03 Uncertainty quantification
