# %% [markdown]
# # M5A_01: Baseline Classification Models
#
# **Track A: Commuter Prediction (Binary Classification)**
#
# ## 🎯 Learning Objectives
# - Create train/validation/test splits
# - Build baseline models (majority class, historical rates)
# - Establish performance benchmarks
# - Define evaluation metrics for classification

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# %% [markdown]
# ## 1. Load Features from Module 4
#
# Load engineered features from Track A.

# %%
# TODO: Load track_a features
# df = pd.read_csv('../../../data/processed/track_a_all_features.csv')
# Create binary target: bikes_available > 0
# df['target'] = (df['bikes_available'] > 0).astype(int)

# %% [markdown]
# ## 2. Train/Validation/Test Split
#
# Time-series aware splitting to prevent data leakage.

# %%
# TODO: Create chronological splits
# Train: 70%, Val: 15%, Test: 15%

# %% [markdown]
# ## 3. Baseline Models
#
# ### Baseline 1: Majority Class

# %%
# TODO: Always predict majority class
# Calculate accuracy, precision, recall

# %% [markdown]
# ### Baseline 2: Historical Availability Rate

# %%
# TODO: Use station-specific availability rates
# If availability_rate > 0.5, predict available

# %% [markdown]
# ## 🔗 Next: M5A_02 Classification models (Logistic, RF, XGBoost)
