# %% [markdown]
# # M5A_02: Classification Models
#
# **Track A: Binary Classification**
#
# ## 🎯 Learning Objectives
# - Train Logistic Regression, Random Forest, XGBoost
# - Compare classification metrics
# - Handle class imbalance
# - Evaluate on validation set

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb

# %% [markdown]
# ## TODO: Implement classification models
# - Logistic Regression (baseline ML model)
# - Random Forest (non-linear patterns)
# - XGBoost (gradient boosting)
# - Handle class imbalance with class_weight
# - Compare precision, recall, F1, ROC-AUC

# %% [markdown]
# ## 🔗 Next: M5A_03 Model selection & tuning
