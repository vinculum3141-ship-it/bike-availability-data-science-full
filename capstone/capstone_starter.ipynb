# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vinculum3141-ship-it/bike-availability-data-science/blob/main/capstone/capstone_starter.ipynb)

# %% [markdown]
# # 🎓 Capstone Project: Bike Availability Prediction
#
# **Student Name**: [Your Name]
# **Date Started**: [Date]
# **Project Goal**: Build an end-to-end ML system to predict bike availability
#
# ---
#
# ## 📋 Project Checklist
#
# Use this notebook as your main workspace. Track your progress below:
#
# ### Phase 1: Data Acquisition
# - [ ] Set up data sources
# - [ ] Collect bike availability data
# - [ ] Collect weather data
# - [ ] Save raw data
#
# ### Phase 2: EDA & Feature Engineering
# - [ ] Data profiling
# - [ ] Exploratory analysis
# - [ ] Feature creation
# - [ ] Data validation
#
# ### Phase 3: Modeling
# - [ ] Train/test splits
# - [ ] Baseline model
# - [ ] Multiple algorithms
# - [ ] Model selection
#
# ### Phase 4: Deployment & Documentation
# - [ ] Dashboard creation
# - [ ] Model documentation
# - [ ] Final report
# - [ ] Code cleanup
#
# ---
#
# ## 📚 Resources
# - [Capstone Guidelines](capstone_guidelines.md)
# - [Grading Rubric](grading_rubric.md)
# - [Notebook Template](../notebooks/notebook_template.ipynb)
# - [Coding Standards](../docs/coding_standards.md)

# %%
# ═══════════════════════════════════════════════════════════
# NOTEBOOK SETUP - Run This Cell First!
# ═══════════════════════════════════════════════════════════

import sys
import os
from datetime import datetime

# Standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configure display
pd.set_option('display.max_columns', None)
plt.style.use('seaborn-v0_8-darkgrid')
# %matplotlib inline

# Check if running in Google Colab
if 'google.colab' in sys.modules:
    print("📍 Running in Google Colab")
    # Uncomment to install requirements
    # !pip install -q -r ../requirements.txt
else:
    print("📍 Running locally")

# Add project root to path
project_root = os.path.abspath('..')
if project_root not in sys.path:
    sys.path.append(project_root)

print(f"✅ Setup complete! Started at: {datetime.now()}")
print(f"📂 Project root: {project_root}")

# %% [markdown]
# ---
#
# ## 1️⃣ Data Acquisition
#
# Collect data from multiple sources. See [Module 02](../notebooks/Module_02_Data_Acquisition/) for guidance.

# %%
# TODO: Add your data acquisition code here
# Example:
# from src.data_acquisition import fetch_bike_data, fetch_weather_data
# 
# bike_df = fetch_bike_data(start_date='2024-01-01', end_date='2024-03-31')
# weather_df = fetch_weather_data(start_date='2024-01-01', end_date='2024-03-31')
# 
# bike_df.to_csv('../data/raw/bike_data_2024.csv', index=False)
# weather_df.to_csv('../data/raw/weather_data_2024.csv', index=False)

pass  # Remove this when you add your code

# %% [markdown]
# ---
#
# ## 2️⃣ Exploratory Data Analysis
#
# Explore your data to understand patterns and quality. See [Module 03](../notebooks/Module_03_Exploration_Profiling/) for guidance.

# %%
# TODO: Add your EDA code here
# Example:
# df = pd.read_csv('../data/raw/bike_data_2024.csv')
# 
# print(df.info())
# print(df.describe())
# 
# # Create visualizations
# plt.figure(figsize=(12, 4))
# df['bikes_available'].hist(bins=50)
# plt.title('Distribution of Bike Availability')
# plt.show()

pass  # Remove this when you add your code

# %% [markdown]
# ---
#
# ## 3️⃣ Feature Engineering
#
# Create meaningful features for your model. See [Module 04](../notebooks/Module_04_Feature_Engineering/) for guidance.

# %%
# TODO: Add your feature engineering code here
# Example:
# from src.feature_engineering import create_time_features, create_lag_features
# 
# df = create_time_features(df)
# df = create_lag_features(df, columns=['bikes_available'], lags=[1, 24, 168])
# 
# df.to_parquet('../data/processed/featured_data_v1.parquet', index=False)

pass  # Remove this when you add your code

# %% [markdown]
# ---
#
# ## 4️⃣ Model Training & Evaluation
#
# Build and compare multiple models. See [Module 05](../notebooks/Module_05_Modeling/) for guidance.

# %%
# TODO: Add your modeling code here
# Example:
# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# 
# # Train/test split
# X = df.drop('bikes_available', axis=1)
# y = df['bikes_available']
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
# 
# # Train model
# model = RandomForestRegressor(n_estimators=100, random_state=42)
# model.fit(X_train, y_train)
# 
# # Evaluate
# y_pred = model.predict(X_test)
# print(f"MAE: {mean_absolute_error(y_test, y_pred):.2f}")
# print(f"RMSE: {mean_squared_error(y_test, y_pred, squared=False):.2f}")
# print(f"R²: {r2_score(y_test, y_pred):.3f}")

pass  # Remove this when you add your code

# %% [markdown]
# ---
#
# ## 5️⃣ Model Validation & Documentation
#
# Validate your model and document its performance. See [Module 06](../notebooks/Module_06_Validation_Governance/) for guidance.

# %%
# TODO: Add validation and documentation
# Example:
# # Error analysis
# errors = y_test - y_pred
# plt.figure(figsize=(10, 6))
# plt.scatter(y_test, errors, alpha=0.5)
# plt.axhline(y=0, color='r', linestyle='--')
# plt.xlabel('Actual Values')
# plt.ylabel('Errors')
# plt.title('Residual Plot')
# plt.show()
# 
# # Feature importance
# importance_df = pd.DataFrame({
#     'feature': X.columns,
#     'importance': model.feature_importances_
# }).sort_values('importance', ascending=False)
# print(importance_df.head(10))

pass  # Remove this when you add your code

# %% [markdown]
# ---
#
# ## 📝 Summary & Next Steps
#
# Document your findings and plan next steps here.

# %% [markdown]
# ### Key Findings
# - TODO: Summarize your main insights
# - TODO: What patterns did you discover?
# - TODO: What worked well?
#
# ### Model Performance
# - TODO: Report final metrics
# - TODO: Compare to baseline
# - TODO: Document limitations
#
# ### Next Steps
# - [ ] Build interactive dashboard
# - [ ] Create model documentation
# - [ ] Write final report
# - [ ] Prepare presentation
#
# ### Lessons Learned
# - TODO: What would you do differently?
# - TODO: What was most challenging?
# - TODO: What did you learn?
#
# ---
#
# **Project Status**: 🚧 In Progress
# **Last Updated**: [Date]
